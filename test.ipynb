# %%
import tkinter as tk
from tkinter import ttk, messagebox
import tkinter.font as tkFont
import datasource as ds
import tkintermapview  # 地圖
import os
import base64
import csv
import pandas as pd


# 標籤
class TKLable(tk.Label):
    def __init__(self, parents, **kwargs):
        super().__init__(parents, **kwargs)
        helv26 = tkFont.Font(family="微軟正黑體", size=12, weight="bold")
        self.config(font=helv26)


# 一般按鈕
class TKButton(tk.Button):
    def __init__(self, parents, **kwargs):
        super().__init__(parents, **kwargs)
        self.config(font=("微軟正黑體", 10, "bold"))


# 主視窗設定
class Window(tk.Tk):
    def __init__(self):
        super().__init__()
        self.config(bg="#345678")

        title = tk.Label(self, text="Fish", bg="#345678")
        titlefont = tkFont.Font(family="微軟正黑體", size=36, weight="bold")
        title.config(font=titlefont, foreground="#FFFFFF")
        title.pack(padx=10, pady=10)

        self.KeywordFrame = ttk.Frame(self, width=800, height=500)
        self.KeywordFrame.pack(fill="both", expand=True)

        mainFrame = tk.Frame(self.KeywordFrame, width=800, height=500)
        mainFrame.pack()

        TKLable(
            mainFrame,
            text="魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚",
            bd=3,
        ).grid(row=0, column=0, columnspan=10, pady=5)

        # 原生種判定下拉選單
        TKLable(mainFrame, text="原生種判定", bd=1).grid(row=1, column=0)
        self.FishType_dict = ds.Get_FISHTYP()
        self.FishTypeValue = tk.StringVar()
        self.FishType_Combo = ttk.Combobox(
            mainFrame,
            values=list(self.FishType_dict.keys()),
            justify="center",
            textvariable=self.FishTypeValue,
        )
        self.FishType_Combo.grid(row=1, column=1)
        self.FishType_Combo.current(0)
        # 下拉選單綁定Function
        self.FishType_Combo.bind("<<ComboboxSelected>>", self.update_second_combobox)

        # 年度下拉選單
        TKLable(mainFrame, text="年度", bd=1).grid(row=1, column=2)
        self.FishYear_dict = ds.Get_FISHYEAR()
        self.FishYearValue = tk.StringVar()
        self.FishYear_Combo = ttk.Combobox(
            mainFrame,
            values=list(self.FishYear_dict.keys()),
            justify="center",
            textvariable=self.FishYearValue,
        )
        self.FishYear_Combo.grid(row=1, column=3)
        self.FishYear_Combo.current(0)

        # 地圖標記下拉選單
        TKLable(mainFrame, text="地圖標記", bd=1).grid(row=1, column=4)
        self.FishMap_dict = ds.Get_MAP()
        self.FishMapValue = tk.StringVar()
        self.FishMap_Combo = ttk.Combobox(
            mainFrame,
            values=list(self.FishMap_dict.keys()),
            justify="center",
            textvariable=self.FishMapValue,
        )
        self.FishMap_Combo.grid(row=1, column=5)
        self.FishMap_Combo.current(0)

        # 中文名下拉選單
        TKLable(mainFrame, text="中文名", bd=3).grid(row=1, column=6)
        self.FishName_dict = ds.Get_FISHNAME()
        self.FishNameValue = tk.StringVar()
        self.FishName_Combo = ttk.Combobox(
            mainFrame,
            values=list(self.FishName_dict.keys()),
            justify="center",
            textvariable=self.FishNameValue,
        )
        self.FishName_Combo.grid(row=1, column=7)
        self.FishName_Combo.current(0)

        # 搜尋按鈕
        self.keyButton = TKButton(mainFrame, text="搜尋", command=self.KeySearch)
        self.keyButton.config(width=80, border=3)

        self.keyButton.grid(row=4, column=0, columnspan=10, pady=(5, 0), sticky="nsew")

        # Map 地圖
        map_box = tk.Canvas(self.KeywordFrame)  # 創建地圖框架
        map_box.pack(fill="both", expand=True, pady=10, padx=100)
        # 創建地圖
        self.map_widget = tkintermapview.TkinterMapView(
            map_box, width=100, height=800, corner_radius=0
        )
        # 引進地圖Function
        self.MarkMap()
        self.MapSet()

    # 地圖Fuction
    def MapSet(self):
        self.map_widget.place(relx=0.5, rely=0.5, anchor=tk.CENTER)
        self.map_widget.pack(fill="both", expand=True, pady=5, padx=80)
        self.map_widget.set_tile_server(
            "https://mt0.google.com/vt/lyrs=m&hl=en&x={x}&y={y}&z={z}&s=Ga", max_zoom=22
        )
        # 設置初始座標(中部)
        self.map_widget.set_position(23.623468547617622, 120.89823983585597)
        self.map_widget.set_zoom(8)

    # 地圖標記Function
    def MarkMap(self):
        self.map_widget.set_position(25.0811164, 121.6052025, marker=True)

    # 下拉選單連結 Function
    def update_second_combobox(self, event):
        selected_tag = self.FishType_dict[self.FishTypeValue.get()]
        # 根据第一个下拉菜单的选项更新第二个下拉菜单的选项
        filtered_names = [
            name for name, tag in self.FishName_dict.items() if tag == selected_tag
        ]
        self.FishName_Combo["values"] = filtered_names
        self.FishName_Combo.current(0)

        # 搜尋條件 未完成 下面都是錯的----------------------------------------------------------------------------

    def KeySearch(self) -> list[list]:
        df = pd.read_csv("Pie_data.csv", encoding="utf-8", low_memory=False)

        fishtype = ""  # 原生種名稱
        fishyear = ""  # 年度
        fishmap = ""  # 地圖標記
        fishname = ""  # 中文名
        for item in df.iterrows():
            print(item[1]["中文名"])
        # print(item[1]["Longitude"])
        # print(item[1]["Latitude"])
        # print("=================")
        '''
        if self.FishTypeValue.get() != "":
            fishtype = self.FishTypeValue.get()
        if self.FishYearValue.get() != "":
            fishyear = self.FishYearValue.get()
        if self.FishMapValue.get() != "":
            fishmap = self.FishMapValue.get()
        if self.FishNameValue.get() != "":
            fishname = self.FishNameValue.get()
        
            fishtype = False
            fishyear = False
            fishmap = False

            x = float(item["Longitude"])  # 25.05081974
            y = float(item["Latitude"])  # 121.5438535
            fishname = (item[1]["中文名"])  # 臺北市中山區復興北路66號
        #print(fishname)
        '''


def main():
    window = Window()
    window.title("Fish")  # title
    window.resizable()  # 禁止拖拉視窗調整視窗大小
    window.geometry("1000x900")  # 視窗大小
    window.mainloop()


if __name__ == "__main__":
    main()
# Out:
# 在目前儲存格或上一個儲存格中執行程式碼時，Kernel 已損毀。請檢閱儲存格中的程式碼，找出失敗的可能原因。如需詳細資訊，請按一下<a href='https://aka.ms/vscodeJupyterKernelCrash'>這裡</a>。檢視 Jupyter <a href='command:jupyter.viewOutput'>記錄</a>，以取得進一步的詳細資料。

# %%
import folium  # 匯入 folium 套件

fmap = folium.Map(location=[35.712326, 139.804037], zoom_start=15)

m1 = folium.Marker(location=[35.709635, 139.810851], popup="<b>Skytree</b>")

m2 = folium.Marker(
    location=[35.707595, 139.795530],
    popup="<i>Hotel</i>",
    icon=folium.Icon(icon="bed", color="green", prefix="fa"),  # Icon類型  # Marker顏色
)  # 使用Font Awesome Icons

m3 = folium.Marker(
    location=[35.715092, 139.796666],
    popup="Asakusa Temple",
    icon=folium.Icon(icon="info-sign", color="red"),
)
center_pos = [35.709635, 139.810851]
fmap = folium.Map(location=center_pos, zoom_start=17)
fmap.add_child(
    folium.Circle(
        location=center_pos,
        color="green",  # Circle 顏色
        radius=30,  # Circle 寬度
        popup="Skytree",  # 彈出視窗內容
        fill=True,  # 填滿中間區域
        fill_opacity=0.5,  # 設定透明度
    )
)
# 將各Marker加入地圖。
fmap.add_child(child=m1)
fmap.add_child(child=m2)
fmap.add_child(child=m3)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f2cfe64f4e40d7f59afe5b2ee57a7c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f2cfe64f4e40d7f59afe5b2ee57a7c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f2cfe64f4e40d7f59afe5b2ee57a7c5 = L.map(
#                 &quot;map_3f2cfe64f4e40d7f59afe5b2ee57a7c5&quot;,
#                 {
#                     center: [35.709635, 139.810851],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_325f68851c0f5b140ed87c69f74b2b66 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_325f68851c0f5b140ed87c69f74b2b66.addTo(map_3f2cfe64f4e40d7f59afe5b2ee57a7c5);
#
#             var circle_1fe0bf92dde5a67e972ffa609c0f69be = L.circle(
#                 [35.709635, 139.810851],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3f2cfe64f4e40d7f59afe5b2ee57a7c5);
#
#
#         var popup_ff194607c40141c50eb6f5c1cf47d02c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3300a68b5b1e3604220680afcd7ef41a = $(`&lt;div id=&quot;html_3300a68b5b1e3604220680afcd7ef41a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Skytree&lt;/div&gt;`)[0];
#                 popup_ff194607c40141c50eb6f5c1cf47d02c.setContent(html_3300a68b5b1e3604220680afcd7ef41a);
#
#
#
#         circle_1fe0bf92dde5a67e972ffa609c0f69be.bindPopup(popup_ff194607c40141c50eb6f5c1cf47d02c)
#         ;
#
#
#
#
#             var marker_5800f0118b1bf589008428eb9a4c12f8 = L.marker(
#                 [35.709635, 139.810851],
#                 {}
#             ).addTo(map_3f2cfe64f4e40d7f59afe5b2ee57a7c5);
#
#
#         var popup_6eac799396070c78b522b42ef815af42 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0473977d26ceded42930cf510a5f9c5e = $(`&lt;div id=&quot;html_0473977d26ceded42930cf510a5f9c5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Skytree&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_6eac799396070c78b522b42ef815af42.setContent(html_0473977d26ceded42930cf510a5f9c5e);
#
#
#
#         marker_5800f0118b1bf589008428eb9a4c12f8.bindPopup(popup_6eac799396070c78b522b42ef815af42)
#         ;
#
#
#
#
#             var marker_13f458b1536e975fc9f53a8488943636 = L.marker(
#                 [35.707595, 139.79553],
#                 {}
#             ).addTo(map_3f2cfe64f4e40d7f59afe5b2ee57a7c5);
#
#
#             var icon_1ed3aa0ef76275f65a54ced00239d86b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bed&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_13f458b1536e975fc9f53a8488943636.setIcon(icon_1ed3aa0ef76275f65a54ced00239d86b);
#
#
#         var popup_18630844d3b96461c0333a7ce04b6217 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ea9f0f98aeba76ee63767e3fc0a2c06f = $(`&lt;div id=&quot;html_ea9f0f98aeba76ee63767e3fc0a2c06f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Hotel&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_18630844d3b96461c0333a7ce04b6217.setContent(html_ea9f0f98aeba76ee63767e3fc0a2c06f);
#
#
#
#         marker_13f458b1536e975fc9f53a8488943636.bindPopup(popup_18630844d3b96461c0333a7ce04b6217)
#         ;
#
#
#
#
#             var marker_6c486a122c9af1c4bee853552f87cac0 = L.marker(
#                 [35.715092, 139.796666],
#                 {}
#             ).addTo(map_3f2cfe64f4e40d7f59afe5b2ee57a7c5);
#
#
#             var icon_8048960fd9e7f73f845e2af21f3fa1ff = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6c486a122c9af1c4bee853552f87cac0.setIcon(icon_8048960fd9e7f73f845e2af21f3fa1ff);
#
#
#         var popup_1a2c05968ea75100bb9540ee25f936c2 = L.popup({&quot;maxWidth&quot;: &quot;1

# %%
import tkinter as tk
from tkinter import ttk, messagebox
import tkinter.font as tkFont
import datasource as ds
import tkintermapview  # 地圖
import os
import base64
import csv
import pandas as pd
import folium
from tkinter import Tk, Frame, Canvas
from tkinterhtml import HtmlFrame


# 標籤
class TKLable(tk.Label):
    def __init__(self, parents, **kwargs):
        super().__init__(parents, **kwargs)
        helv26 = tkFont.Font(family="微軟正黑體", size=12, weight="bold")
        self.config(font=helv26)


# 一般按鈕
class TKButton(tk.Button):
    def __init__(self, parents, **kwargs):
        super().__init__(parents, **kwargs)
        self.config(font=("微軟正黑體", 10, "bold"))


# 主視窗設定
class Window(tk.Tk):
    def __init__(self):
        super().__init__()
        self.config(bg="#345678")

        title = tk.Label(self, text="Fish", bg="#345678")
        titlefont = tkFont.Font(family="微軟正黑體", size=36, weight="bold")
        title.config(font=titlefont, foreground="#FFFFFF")
        title.pack(padx=10, pady=10)

        self.KeywordFrame = ttk.Frame(self, width=800, height=500)
        self.KeywordFrame.pack(fill="both", expand=True)

        mainFrame = tk.Frame(self.KeywordFrame, width=800, height=500)
        mainFrame.pack()

        TKLable(
            mainFrame,
            text="魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚",
            bd=3,
        ).grid(row=0, column=0, columnspan=10, pady=5)

        # 原生種判定下拉選單
        TKLable(mainFrame, text="原生種判定", bd=1).grid(row=1, column=0)
        self.FishType_dict = ds.Get_FISHTYP()
        self.FishTypeValue = tk.StringVar()
        self.FishType_Combo = ttk.Combobox(
            mainFrame,
            values=list(self.FishType_dict.keys()),
            justify="center",
            textvariable=self.FishTypeValue,
        )
        self.FishType_Combo.grid(row=1, column=1)
        self.FishType_Combo.current(0)
        # 下拉選單綁定Function
        self.FishType_Combo.bind("<<ComboboxSelected>>", self.update_second_combobox)

        # 年度下拉選單
        TKLable(mainFrame, text="年度", bd=1).grid(row=1, column=2)
        self.FishYear_dict = ds.Get_FISHYEAR()
        self.FishYearValue = tk.StringVar()
        self.FishYear_Combo = ttk.Combobox(
            mainFrame,
            values=list(self.FishYear_dict.keys()),
            justify="center",
            textvariable=self.FishYearValue,
        )
        self.FishYear_Combo.grid(row=1, column=3)
        self.FishYear_Combo.current(0)

        # 地圖標記下拉選單
        TKLable(mainFrame, text="地圖標記", bd=1).grid(row=1, column=4)
        self.FishMap_dict = ds.Get_MAP()
        self.FishMapValue = tk.StringVar()
        self.FishMap_Combo = ttk.Combobox(
            mainFrame,
            values=list(self.FishMap_dict.keys()),
            justify="center",
            textvariable=self.FishMapValue,
        )
        self.FishMap_Combo.grid(row=1, column=5)
        self.FishMap_Combo.current(0)

        # 中文名下拉選單
        TKLable(mainFrame, text="中文名", bd=3).grid(row=1, column=6)
        self.FishName_dict = ds.Get_FISHNAME()
        self.FishNameValue = tk.StringVar()
        self.FishName_Combo = ttk.Combobox(
            mainFrame,
            values=list(self.FishName_dict.keys()),
            justify="center",
            textvariable=self.FishNameValue,
        )
        self.FishName_Combo.grid(row=1, column=7)
        self.FishName_Combo.current(0)

        # 搜尋按鈕
        self.keyButton = TKButton(mainFrame, text="搜尋", command=self.KeySearch)
        self.keyButton.config(width=80, border=3)

        self.keyButton.grid(row=4, column=0, columnspan=10, pady=(5, 0), sticky="nsew")

        # Map 地圖
        map_box = tk.Canvas(self.KeywordFrame)  # 創建地圖框架
        map_box.pack(fill="both", expand=True, pady=10, padx=100)
        # 創建地圖
        self.map_widget = tkintermapview.TkinterMapView(
            map_box, width=100, height=800, corner_radius=0
        )
        fmap = folium.Map(location=[35.709635, 139.810851], zoom_start=16)

        html_frame = HtmlFrame(map_box)

        html_frame.pack(fill="both", expand=True)


        # 获取地图的HTML字符串
        map_html = fmap._repr_html_()
        self.map_widget(map_html)
        # 引進地圖Function
        # self.MarkMap()
        # self.MapSet()

    # 地圖Fuction
    def MapSet():
        folium.Map(location=[35.709635, 139.810851], zoom_start=16)

    # 地圖標記Function
    def MarkMap(self):
        self.map_widget.set_position(25.0811164, 121.6052025, marker=True)

    # 下拉選單連結 Function
    def update_second_combobox(self, event):
        selected_tag = self.FishType_dict[self.FishTypeValue.get()]
        # 根据第一个下拉菜单的选项更新第二个下拉菜单的选项
        filtered_names = [
            name for name, tag in self.FishName_dict.items() if tag == selected_tag
        ]
        self.FishName_Combo["values"] = filtered_names
        self.FishName_Combo.current(0)

        # 搜尋條件 未完成 下面都是錯的----------------------------------------------------------------------------

    def KeySearch(self) -> list[list]:
        df = pd.read_csv("Pie_data.csv", encoding="utf-8", low_memory=False)
        for item in df.iterrows():
            print(item[1]["中文名"])
            print(item[1]["Longitude"])
            print(item[1]["Latitude"])
            print("=================")
            # 要先查資料類型


def main():
    window = Window()
    window.title("Fish")  # title
    window.resizable()  # 禁止拖拉視窗調整視窗大小
    window.geometry("1000x900")  # 視窗大小
    window.mainloop()


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\User\Desktop\教學資料\github檔案\FISH\test.ipynb 儲存格 3 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/%E6%95%99%E5%AD%B8%E8%B3%87%E6%96%99/github%E6%AA%94%E6%A1%88/FISH/test.ipynb#W2sZmlsZQ%3D%3D?line=160'>161</a>     window.mainloop()
#     <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/%E6%95%99%E5%AD%B8%E8%B3%87%E6%96%99/github%E6%AA%94%E6%A1%88/FISH/test.ipynb#W2sZmlsZQ%3D%3D?line=163'>164</a> if __name__ == "__main__":
# --> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/%E6%95%99%E5%AD%B8%E8%B3%87%E6%96%99/github%E6%AA%94%E6%A1%88/FISH/test.ipynb#W2sZmlsZQ%3D%3D?line=164'>165</a>     main()
#
# c:\Users\User\Desktop\教學資料\github檔案\FISH\test.ipynb 儲存格 3 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/%E6%95%99%E5%AD%B8%E8%B3%87%E6%96%99/github%E6%AA%94%E6%A1%88/FISH/test.ipynb#W2sZmlsZQ%3D%3D?line=155'>156</a> def main():
# --> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/%E6%95%99%E5%AD%B8%E8%B3%87%E6%96%99/github%E6%AA%94%E6%A1%88/FISH/test.ipynb#W2sZmlsZQ%3D%3D?line=156'>157</a>     window = Window()
#     <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/%E6%95%99%E5%AD%B8%E8%B3%87%E6%96%99/github%E6%AA%94%E6%A1%88/FISH/test.ipynb#W2sZmlsZQ%3D%3D?line=157'>158</a>     window.title("Fish")  # title
#     <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/%E6%95%99%E5%AD%B8%E8%B3%87%E6%96%99/github%E6%AA%94%E6%A1%88/FISH/test.ipynb#W2sZmlsZQ%3D%3D?line=158'>159</a>     window.resizable()  # 禁止拖拉視窗調整視窗大小
#
# c:\Users\User\Desktop\教學資料\github檔案\FISH\test.ipynb 儲存格 3 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/%E6%95%99%E5%AD%B8%E8%B3%87%E6%96%99/github%E6%AA%94%E6%A1%88/FISH/test.ipynb#W2sZmlsZQ%3D%3D?line=116'>117</a> self.map_widget = tkintermapview.TkinterMapView(
#     <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/%E6%95%99%E5%AD%B8%E8%B3%87%E6%96%99/github%E6%AA%94%E6%A1%88/FISH/test.ipynb#W2sZmlsZQ%3D%3D?line=117'>118</a>     map_box, width=100, height=800, corner_radius=0
#     <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/%E6%95%99%E5%AD%B8%E8%B3%87%E6%96%99/github%E6%AA%94%E6%A1%88/FISH/test.ipynb#W2sZmlsZQ%3D%3D?line=118'>119</a> )
#     <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/%E6%95%99%E5%AD%B8%E8%B3%87%E6%96%99/github%E6%AA%94%E6%A1%88/FISH/test.ipynb#W2sZmlsZQ%3D%3D?line=119'>120</a> fmap = folium.Map(location=[35.709635, 139.810851], zoom_start=16)
# --> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/%E6%95%99%E5%AD%B8%E8%B3%87%E6%96%99/github%E6%AA%94%E6%A1%88/FISH/test.ipynb#W2sZmlsZQ%3D%3D?line=120'>121</a> self.map_widget(fmap)
#
# TypeError: 'TkinterMapView' object is not callable
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
# <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'
# Exception ignored in: <function PhotoImage.__del__ at 0x0000020C845413F0>
# Traceback (most recent call last):
#   File "c:\python3.10.8\lib\site-packages\PIL\ImageTk.py", line 131, in __del__
#     name = self.__photo.name
# AttributeError: 'PhotoImage' object has no attribute '_PhotoImage__photo'

# %%
import tkinter as tk
from tkinter import ttk, messagebox
import tkinter.font as tkFont
import datasource as ds
import tkintermapview  # 地圖
import os
import base64
import csv
import pandas as pd


# 標籤
class TKLable(tk.Label):
    def __init__(self, parents, **kwargs):
        super().__init__(parents, **kwargs)
        helv26 = tkFont.Font(family="微軟正黑體", size=12, weight="bold")
        self.config(font=helv26)


# 一般按鈕
class TKButton(tk.Button):
    def __init__(self, parents, **kwargs):
        super().__init__(parents, **kwargs)
        self.config(font=("微軟正黑體", 10, "bold"))


# 主視窗設定
class Window(tk.Tk):
    def __init__(self):
        super().__init__()
        self.config(bg="#345678")

        title = tk.Label(self, text="Fish", bg="#345678")
        titlefont = tkFont.Font(family="微軟正黑體", size=36, weight="bold")
        title.config(font=titlefont, foreground="#FFFFFF")
        title.pack(padx=10, pady=10)

        self.KeywordFrame = ttk.Frame(self, width=800, height=500)
        self.KeywordFrame.pack(fill="both", expand=True)

        mainFrame = tk.Frame(self.KeywordFrame, width=800, height=500)
        mainFrame.pack()

        TKLable(
            mainFrame,
            text="魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚魚",
            bd=3,
        ).grid(row=0, column=0, columnspan=10, pady=5)

        # 原生種判定下拉選單
        TKLable(mainFrame, text="原生種判定", bd=1).grid(row=1, column=0)
        self.FishType_dict = ds.Get_FISHTYP()
        self.FishTypeValue = tk.StringVar()
        self.FishType_Combo = ttk.Combobox(
            mainFrame,
            values=list(self.FishType_dict.keys()),
            justify="center",
            textvariable=self.FishTypeValue,
        )
        self.FishType_Combo.grid(row=1, column=1)
        self.FishType_Combo.current(0)
        # 下拉選單綁定Function
        self.FishType_Combo.bind("<<ComboboxSelected>>", self.update_second_combobox)

        # 年度下拉選單
        TKLable(mainFrame, text="年度", bd=1).grid(row=1, column=2)
        self.FishYear_dict = ds.Get_FISHYEAR()
        self.FishYearValue = tk.StringVar()
        self.FishYear_Combo = ttk.Combobox(
            mainFrame,
            values=list(self.FishYear_dict.keys()),
            justify="center",
            textvariable=self.FishYearValue,
        )
        self.FishYear_Combo.grid(row=1, column=3)
        self.FishYear_Combo.current(0)

        # 地圖標記下拉選單
        TKLable(mainFrame, text="地圖標記", bd=1).grid(row=1, column=4)
        self.FishMap_dict = ds.Get_MAP()
        self.FishMapValue = tk.StringVar()
        self.FishMap_Combo = ttk.Combobox(
            mainFrame,
            values=list(self.FishMap_dict.keys()),
            justify="center",
            textvariable=self.FishMapValue,
        )
        self.FishMap_Combo.grid(row=1, column=5)
        self.FishMap_Combo.current(0)

        # 中文名下拉選單
        TKLable(mainFrame, text="中文名", bd=3).grid(row=1, column=6)
        self.FishName_dict = ds.Get_FISHNAME()
        self.FishNameValue = tk.StringVar()
        self.FishName_Combo = ttk.Combobox(
            mainFrame,
            values=list(self.FishName_dict.keys()),
            justify="center",
            textvariable=self.FishNameValue,
        )
        self.FishName_Combo.grid(row=1, column=7)
        self.FishName_Combo.current(0)

        # 搜尋按鈕
        self.keyButton = TKButton(mainFrame, text="搜尋", command=self.KeySearch)
        self.keyButton.config(width=80, border=3)

        self.keyButton.grid(row=4, column=0, columnspan=10, pady=(5, 0), sticky="nsew")

        # Map 地圖
        map_box = tk.Canvas(self.KeywordFrame)  # 創建地圖框架
        map_box.pack(fill="both", expand=True, pady=10, padx=100)
        # 創建地圖
        self.map_widget = tkintermapview.TkinterMapView(
            map_box, width=100, height=800, corner_radius=0
        )
        # 引進地圖Function
        self.MarkMap()
        self.MapSet()

    # 地圖Fuction
    def MapSet(self):
        self.map_widget.place(relx=0.5, rely=0.5, anchor=tk.CENTER)
        self.map_widget.pack(fill="both", expand=True, pady=5, padx=80)
        self.map_widget.set_tile_server(
            "https://mt0.google.com/vt/lyrs=m&hl=en&x={x}&y={y}&z={z}&s=Ga", max_zoom=22
        )
        # 設置初始座標(中部)
        self.map_widget.set_position(23.623468547617622, 120.89823983585597)
        self.map_widget.set_zoom(8)

    # 地圖標記Function
    def MarkMap(self):
        self.map_widget.set_position(25.0811164, 121.6052025, marker=True)

    # 下拉選單連結 Function
    def update_second_combobox(self, event):
        selected_tag = self.FishType_dict[self.FishTypeValue.get()]
        # 根据第一个下拉菜单的选项更新第二个下拉菜单的选项
        filtered_names = [
            name for name, tag in self.FishName_dict.items() if tag == selected_tag
        ]
        self.FishName_Combo["values"] = filtered_names
        self.FishName_Combo.current(0)

        # 搜尋條件 未完成 下面都是錯的----------------------------------------------------------------------------

    def KeySearch(self) -> list[list]:
        df = pd.read_csv("Pie_data.csv", encoding="utf-8", low_memory=False)
        for item in df.iterrows():
            print(item)
            #print(item[1]["中文名"])
            #print(item[1]["Longitude"])
            #print(item[1]["Latitude"])
            #print("=================")
            # 要先查資料類型
            break


def main():
    window = Window()
    window.title("Fish")  # title
    window.resizable()  # 禁止拖拉視窗調整視窗大小
    window.geometry("1000x900")  # 視窗大小
    window.mainloop()


if __name__ == "__main__":
    main()
# Out:
# 在目前儲存格或上一個儲存格中執行程式碼時，Kernel 已損毀。請檢閱儲存格中的程式碼，找出失敗的可能原因。如需詳細資訊，請按一下<a href='https://aka.ms/vscodeJupyterKernelCrash'>這裡</a>。檢視 Jupyter <a href='command:jupyter.viewOutput'>記錄</a>，以取得進一步的詳細資料。
